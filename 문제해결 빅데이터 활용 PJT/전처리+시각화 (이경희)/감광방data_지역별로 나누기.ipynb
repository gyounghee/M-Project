# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/멀티캠퍼스/2조/이경희/수산물_위판정보_전처리완료.csv')

# %% [markdown]
# # 광어

# %%
suhyup = ['인천', '서산', '안면도', '대천서부', '서천서부', '군산시', '목포', '전남서부어류양식', '고흥군', '여수', '남해군', '통영', '거제', '부산시', '울산', '포항', '삼척', '강릉시', '속초시', '동해시']

# for suhyup_name in suhyup 
Incheon, Seosan, Anmyeondo, Daecheon, Seocheon, Gunsan, Mokpo = [], [], [], [], [], [], []
Jeonnam_western_fish_farming, Goheung_gun, Yeosu, Namhae_gun =  [], [], [], []
Tongyeong, Geoje, Busan, Ulsan, Pohang, Samcheok, Gangneung, Sokcho, Donghae = [], [], [], [], [], [], [], [], []

for suhyup_name in suhyup:
  for row in range(len(df)):
    if df.loc[row,'수산물표준코드명'] == "광어" and df.loc[row,'산지조합명'] == '인천' : Incheon.append(df.loc[row])
    elif df.loc[row,'수산물표준코드명'] == "광어" and df.loc[row,'산지조합명'] == '서산' : Seosan.append(df.loc[row])
    elif df.loc[row,'수산물표준코드명'] == "광어" and df.loc[row,'산지조합명'] == '안면도' : Anmyeondo.append(df.loc[row])
    elif df.loc[row,'수산물표준코드명'] == "광어" and df.loc[row,'산지조합명'] == '대천서부' : Daecheon.append(df.loc[row])
    elif df.loc[row,'수산물표준코드명'] == "광어" and df.loc[row,'산지조합명'] == '서천서부' : Seocheon.append(df.loc[row])
    elif df.loc[row,'수산물표준코드명'] == "광어" and df.loc[row,'산지조합명'] == '군산시' : Gunsan.append(df.loc[row])
    elif df.loc[row,'수산물표준코드명'] == "광어" and df.loc[row,'산지조합명'] == '목포시' : Mokpo.append(df.loc[row])
    elif df.loc[row,'수산물표준코드명'] == "광어" and df.loc[row,'산지조합명'] == '전남서부어류양식' : Jeonnam_western_fish_farming.append(df.loc[row])
    elif df.loc[row,'수산물표준코드명'] == "광어" and df.loc[row,'산지조합명'] == '고흥군' : Goheung_gun.append(df.loc[row])
    elif df.loc[row,'수산물표준코드명'] == "광어" and df.loc[row,'산지조합명'] == '여수' : Yeosu.append(df.loc[row])
    elif df.loc[row,'수산물표준코드명'] == "광어" and df.loc[row,'산지조합명'] == '남해군' : Namhae_gun.append(df.loc[row])
    elif df.loc[row,'수산물표준코드명'] == "광어" and df.loc[row,'산지조합명'] == '통영' : Tongyeong.append(df.loc[row])
    elif df.loc[row,'수산물표준코드명'] == "광어" and df.loc[row,'산지조합명'] == '거제' : Geoje.append(df.loc[row])
    elif df.loc[row,'수산물표준코드명'] == "광어" and df.loc[row,'산지조합명'] == '부산시' : Busan.append(df.loc[row])
    elif df.loc[row,'수산물표준코드명'] == "광어" and df.loc[row,'산지조합명'] == '울산' : Ulsan.append(df.loc[row])
    elif df.loc[row,'수산물표준코드명'] == "광어" and df.loc[row,'산지조합명'] == '포항' : Pohang.append(df.loc[row])
    elif df.loc[row,'수산물표준코드명'] == "광어" and df.loc[row,'산지조합명'] == '삼척' : Samcheok.append(df.loc[row])
    elif df.loc[row,'수산물표준코드명'] == "광어" and df.loc[row,'산지조합명'] == '강릉시' : Gangneung.append(df.loc[row])
    elif df.loc[row,'수산물표준코드명'] == "광어" and df.loc[row,'산지조합명'] == '속초시' : Sokcho.append(df.loc[row])
    elif df.loc[row,'수산물표준코드명'] == "광어" and df.loc[row,'산지조합명'] == '동해시' : Donghae.append(df.loc[row])

# %%
# DF로 변환
Incheon = pd.DataFrame(Incheon) ; Incheon.reset_index(drop=True, inplace=True) 
Seosan = pd.DataFrame(Seosan) ; Seosan.reset_index(drop=True, inplace=True) 
Anmyeondo = pd.DataFrame(Anmyeondo) ; Anmyeondo.reset_index(drop=True, inplace=True) 
Daecheon = pd.DataFrame(Daecheon) ; Daecheon.reset_index(drop=True, inplace=True) 
Seocheon = pd.DataFrame(Seocheon) ; Seocheon.reset_index(drop=True, inplace=True) 
Gunsan = pd.DataFrame(Gunsan) ; Gunsan.reset_index(drop=True, inplace=True) 
Mokpo = pd.DataFrame(Mokpo) ; Mokpo.reset_index(drop=True, inplace=True) 
Jeonnam_western_fish_farming = pd.DataFrame(Jeonnam_western_fish_farming) ; Jeonnam_western_fish_farming.reset_index(drop=True, inplace=True) 
Goheung_gun = pd.DataFrame(Goheung_gun) ; Goheung_gun.reset_index(drop=True, inplace=True) 
Yeosu = pd.DataFrame(Yeosu) ; Yeosu.reset_index(drop=True, inplace=True) 
Namhae_gun = pd.DataFrame(Namhae_gun) ; Namhae_gun.reset_index(drop=True, inplace=True) 
Tongyeong = pd.DataFrame(Tongyeong) ; Tongyeong.reset_index(drop=True, inplace=True) 
Geoje = pd.DataFrame(Geoje) ; Geoje.reset_index(drop=True, inplace=True) 
Busan = pd.DataFrame(Busan) ; Busan.reset_index(drop=True, inplace=True) 
Ulsan = pd.DataFrame(Ulsan) ; Ulsan.reset_index(drop=True, inplace=True) 
Pohang = pd.DataFrame(Pohang) ; Pohang.reset_index(drop=True, inplace=True) 
Samcheok = pd.DataFrame(Samcheok) ; Samcheok.reset_index(drop=True, inplace=True) 
Gangneung = pd.DataFrame(Gangneung) ; Gangneung.reset_index(drop=True, inplace=True) 
Sokcho = pd.DataFrame(Sokcho) ; Sokcho.reset_index(drop=True, inplace=True) 
Donghae = pd.DataFrame(Donghae) ; Donghae.reset_index(drop=True, inplace=True)

# %%
# csv파일로 저장
pd.DataFrame(Incheon).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/광어/Incheon.csv', index=False)
pd.DataFrame(Seosan).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/광어/Seosan.csv', index=False)
pd.DataFrame(Anmyeondo).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/광어/Anmyeondo.csv', index=False)
pd.DataFrame(Daecheon).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/광어/Daecheon.csv', index=False)
pd.DataFrame(Seocheon).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/광어/Seocheon.csv', index=False)
pd.DataFrame(Gunsan).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/광어/Gunsan.csv', index=False)
pd.DataFrame(Mokpo).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/광어/Mokpo.csv', index=False)
pd.DataFrame(Jeonnam_western_fish_farming).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/광어/Jeonnam_western_fish_farming.csv', index=False)
pd.DataFrame(Goheung_gun).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/광어/Goheung_gun.csv', index=False)
pd.DataFrame(Yeosu).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/광어/Yeosu.csv', index=False)
pd.DataFrame(Namhae_gun).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/광어/Namhae_gun.csv', index=False)
pd.DataFrame(Tongyeong).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/광어/Tongyeong.csv', index=False)
pd.DataFrame(Geoje).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/광어/Geoje.csv', index=False)
pd.DataFrame(Busan).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/광어/Busan.csv', index=False)
pd.DataFrame(Ulsan).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/광어/Ulsan.csv', index=False)
pd.DataFrame(Pohang).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/광어/Pohang.csv', index=False)
pd.DataFrame(Samcheok).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/광어/Samcheok.csv', index=False)
pd.DataFrame(Gangneung).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/광어/Gangneung.csv', index=False)
pd.DataFrame(Sokcho).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/광어/Sokcho.csv', index=False)
pd.DataFrame(Donghae).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/광어/Donghae.csv', index=False)

# %% [markdown]
# # 방어

# %%
suhyup = ['인천', '서산', '안면도', '대천서부', '서천서부', '군산시', '목포', '전남서부어류양식', '고흥군', '여수', '남해군', '통영', '거제', '부산시', '울산', '포항', '삼척', '강릉시', '속초시', '동해시']

# for suhyup_name in suhyup 
Incheon, Seosan, Anmyeondo, Daecheon, Seocheon, Gunsan, Mokpo = [], [], [], [], [], [], []
Jeonnam_western_fish_farming, Goheung_gun, Yeosu, Namhae_gun =  [], [], [], []
Tongyeong, Geoje, Busan, Ulsan, Pohang, Samcheok, Gangneung, Sokcho, Donghae = [], [], [], [], [], [], [], [], []

for suhyup_name in suhyup:
  for row in range(len(df)):
    if df.loc[row,'수산물표준코드명'] == "방어" and df.loc[row,'산지조합명'] == '인천' : Incheon.append(df.loc[row])
    elif df.loc[row,'수산물표준코드명'] == "방어" and df.loc[row,'산지조합명'] == '서산' : Seosan.append(df.loc[row])
    elif df.loc[row,'수산물표준코드명'] == "방어" and df.loc[row,'산지조합명'] == '안면도' : Anmyeondo.append(df.loc[row])
    elif df.loc[row,'수산물표준코드명'] == "방어" and df.loc[row,'산지조합명'] == '대천서부' : Daecheon.append(df.loc[row])
    elif df.loc[row,'수산물표준코드명'] == "방어" and df.loc[row,'산지조합명'] == '서천서부' : Seocheon.append(df.loc[row])
    elif df.loc[row,'수산물표준코드명'] == "방어" and df.loc[row,'산지조합명'] == '군산시' : Gunsan.append(df.loc[row])
    elif df.loc[row,'수산물표준코드명'] == "방어" and df.loc[row,'산지조합명'] == '목포시' : Mokpo.append(df.loc[row])
    elif df.loc[row,'수산물표준코드명'] == "방어" and df.loc[row,'산지조합명'] == '전남서부어류양식' : Jeonnam_western_fish_farming.append(df.loc[row])
    elif df.loc[row,'수산물표준코드명'] == "방어" and df.loc[row,'산지조합명'] == '고흥군' : Goheung_gun.append(df.loc[row])
    elif df.loc[row,'수산물표준코드명'] == "방어" and df.loc[row,'산지조합명'] == '여수' : Yeosu.append(df.loc[row])
    elif df.loc[row,'수산물표준코드명'] == "방어" and df.loc[row,'산지조합명'] == '남해군' : Namhae_gun.append(df.loc[row])
    elif df.loc[row,'수산물표준코드명'] == "방어" and df.loc[row,'산지조합명'] == '통영' : Tongyeong.append(df.loc[row])
    elif df.loc[row,'수산물표준코드명'] == "방어" and df.loc[row,'산지조합명'] == '거제' : Geoje.append(df.loc[row])
    elif df.loc[row,'수산물표준코드명'] == "방어" and df.loc[row,'산지조합명'] == '부산시' : Busan.append(df.loc[row])
    elif df.loc[row,'수산물표준코드명'] == "방어" and df.loc[row,'산지조합명'] == '울산' : Ulsan.append(df.loc[row])
    elif df.loc[row,'수산물표준코드명'] == "방어" and df.loc[row,'산지조합명'] == '포항' : Pohang.append(df.loc[row])
    elif df.loc[row,'수산물표준코드명'] == "방어" and df.loc[row,'산지조합명'] == '삼척' : Samcheok.append(df.loc[row])
    elif df.loc[row,'수산물표준코드명'] == "방어" and df.loc[row,'산지조합명'] == '강릉시' : Gangneung.append(df.loc[row])
    elif df.loc[row,'수산물표준코드명'] == "방어" and df.loc[row,'산지조합명'] == '속초시' : Sokcho.append(df.loc[row])
    elif df.loc[row,'수산물표준코드명'] == "방어" and df.loc[row,'산지조합명'] == '동해시' : Donghae.append(df.loc[row])

# %%
# DF로 변환
Incheon = pd.DataFrame(Incheon) ; Incheon.reset_index(drop=True, inplace=True) 
Seosan = pd.DataFrame(Seosan) ; Seosan.reset_index(drop=True, inplace=True) 
Anmyeondo = pd.DataFrame(Anmyeondo) ; Anmyeondo.reset_index(drop=True, inplace=True) 
Daecheon = pd.DataFrame(Daecheon) ; Daecheon.reset_index(drop=True, inplace=True) 
Seocheon = pd.DataFrame(Seocheon) ; Seocheon.reset_index(drop=True, inplace=True) 
Gunsan = pd.DataFrame(Gunsan) ; Gunsan.reset_index(drop=True, inplace=True) 
Mokpo = pd.DataFrame(Mokpo) ; Mokpo.reset_index(drop=True, inplace=True) 
Jeonnam_western_fish_farming = pd.DataFrame(Jeonnam_western_fish_farming) ; Jeonnam_western_fish_farming.reset_index(drop=True, inplace=True) 
Goheung_gun = pd.DataFrame(Goheung_gun) ; Goheung_gun.reset_index(drop=True, inplace=True) 
Yeosu = pd.DataFrame(Yeosu) ; Yeosu.reset_index(drop=True, inplace=True) 
Namhae_gun = pd.DataFrame(Namhae_gun) ; Namhae_gun.reset_index(drop=True, inplace=True) 
Tongyeong = pd.DataFrame(Tongyeong) ; Tongyeong.reset_index(drop=True, inplace=True) 
Geoje = pd.DataFrame(Geoje) ; Geoje.reset_index(drop=True, inplace=True) 
Busan = pd.DataFrame(Busan) ; Busan.reset_index(drop=True, inplace=True) 
Ulsan = pd.DataFrame(Ulsan) ; Ulsan.reset_index(drop=True, inplace=True) 
Pohang = pd.DataFrame(Pohang) ; Pohang.reset_index(drop=True, inplace=True) 
Samcheok = pd.DataFrame(Samcheok) ; Samcheok.reset_index(drop=True, inplace=True) 
Gangneung = pd.DataFrame(Gangneung) ; Gangneung.reset_index(drop=True, inplace=True) 
Sokcho = pd.DataFrame(Sokcho) ; Sokcho.reset_index(drop=True, inplace=True) 
Donghae = pd.DataFrame(Donghae) ; Donghae.reset_index(drop=True, inplace=True)

# %%
# csv파일로 저장
pd.DataFrame(Incheon).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/방어/Incheon.csv', index=False)
pd.DataFrame(Seosan).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/방어/Seosan.csv', index=False)
pd.DataFrame(Anmyeondo).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/방어/Anmyeondo.csv', index=False)
pd.DataFrame(Daecheon).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/방어/Daecheon.csv', index=False)
pd.DataFrame(Seocheon).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/방어/Seocheon.csv', index=False)
pd.DataFrame(Gunsan).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/방어/Gunsan.csv', index=False)
pd.DataFrame(Mokpo).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/방어/Mokpo.csv', index=False)
pd.DataFrame(Jeonnam_western_fish_farming).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/방어/Jeonnam_western_fish_farming.csv', index=False)
pd.DataFrame(Goheung_gun).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/방어/Goheung_gun.csv', index=False)
pd.DataFrame(Yeosu).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/방어/Yeosu.csv', index=False)
pd.DataFrame(Namhae_gun).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/방어/Namhae_gun.csv', index=False)
pd.DataFrame(Tongyeong).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/방어/Tongyeong.csv', index=False)
pd.DataFrame(Geoje).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/방어/Geoje.csv', index=False)
pd.DataFrame(Busan).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/방어/Busan.csv', index=False)
pd.DataFrame(Ulsan).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/방어/Ulsan.csv', index=False)
pd.DataFrame(Pohang).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/방어/Pohang.csv', index=False)
pd.DataFrame(Samcheok).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/방어/Samcheok.csv', index=False)
pd.DataFrame(Gangneung).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/방어/Gangneung.csv', index=False)
pd.DataFrame(Sokcho).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/방어/Sokcho.csv', index=False)
pd.DataFrame(Donghae).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/방어/Donghae.csv', index=False)

# %% [markdown]
# # 감성돔

# %%
suhyup = ['인천', '서산', '안면도', '대천서부', '서천서부', '군산시', '목포', '전남서부어류양식', '고흥군', '여수', '남해군', '통영', '거제', '부산시', '울산', '포항', '삼척', '강릉시', '속초시', '동해시']

# for suhyup_name in suhyup 
Incheon, Seosan, Anmyeondo, Daecheon, Seocheon, Gunsan, Mokpo = [], [], [], [], [], [], []
Jeonnam_western_fish_farming, Goheung_gun, Yeosu, Namhae_gun =  [], [], [], []
Tongyeong, Geoje, Busan, Ulsan, Pohang, Samcheok, Gangneung, Sokcho, Donghae = [], [], [], [], [], [], [], [], []

for suhyup_name in suhyup:
  for row in range(len(df)):
    if df.loc[row,'수산물표준코드명'] == "감성돔" and df.loc[row,'산지조합명'] == '인천' : Incheon.append(df.loc[row])
    elif df.loc[row,'수산물표준코드명'] == "감성돔" and df.loc[row,'산지조합명'] == '서산' : Seosan.append(df.loc[row])
    elif df.loc[row,'수산물표준코드명'] == "감성돔" and df.loc[row,'산지조합명'] == '안면도' : Anmyeondo.append(df.loc[row])
    elif df.loc[row,'수산물표준코드명'] == "감성돔" and df.loc[row,'산지조합명'] == '대천서부' : Daecheon.append(df.loc[row])
    elif df.loc[row,'수산물표준코드명'] == "감성돔" and df.loc[row,'산지조합명'] == '서천서부' : Seocheon.append(df.loc[row])
    elif df.loc[row,'수산물표준코드명'] == "감성돔" and df.loc[row,'산지조합명'] == '군산시' : Gunsan.append(df.loc[row])
    elif df.loc[row,'수산물표준코드명'] == "감성돔" and df.loc[row,'산지조합명'] == '목포시' : Mokpo.append(df.loc[row])
    elif df.loc[row,'수산물표준코드명'] == "감성돔" and df.loc[row,'산지조합명'] == '전남서부어류양식' : Jeonnam_western_fish_farming.append(df.loc[row])
    elif df.loc[row,'수산물표준코드명'] == "감성돔" and df.loc[row,'산지조합명'] == '고흥군' : Goheung_gun.append(df.loc[row])
    elif df.loc[row,'수산물표준코드명'] == "감성돔" and df.loc[row,'산지조합명'] == '여수' : Yeosu.append(df.loc[row])
    elif df.loc[row,'수산물표준코드명'] == "감성돔" and df.loc[row,'산지조합명'] == '남해군' : Namhae_gun.append(df.loc[row])
    elif df.loc[row,'수산물표준코드명'] == "감성돔" and df.loc[row,'산지조합명'] == '통영' : Tongyeong.append(df.loc[row])
    elif df.loc[row,'수산물표준코드명'] == "감성돔" and df.loc[row,'산지조합명'] == '거제' : Geoje.append(df.loc[row])
    elif df.loc[row,'수산물표준코드명'] == "감성돔" and df.loc[row,'산지조합명'] == '부산시' : Busan.append(df.loc[row])
    elif df.loc[row,'수산물표준코드명'] == "감성돔" and df.loc[row,'산지조합명'] == '울산' : Ulsan.append(df.loc[row])
    elif df.loc[row,'수산물표준코드명'] == "감성돔" and df.loc[row,'산지조합명'] == '포항' : Pohang.append(df.loc[row])
    elif df.loc[row,'수산물표준코드명'] == "감성돔" and df.loc[row,'산지조합명'] == '삼척' : Samcheok.append(df.loc[row])
    elif df.loc[row,'수산물표준코드명'] == "감성돔" and df.loc[row,'산지조합명'] == '강릉시' : Gangneung.append(df.loc[row])
    elif df.loc[row,'수산물표준코드명'] == "감성돔" and df.loc[row,'산지조합명'] == '속초시' : Sokcho.append(df.loc[row])
    elif df.loc[row,'수산물표준코드명'] == "감성돔" and df.loc[row,'산지조합명'] == '동해시' : Donghae.append(df.loc[row])

# %%
# DF로 변환
Incheon = pd.DataFrame(Incheon) ; Incheon.reset_index(drop=True, inplace=True) 
Seosan = pd.DataFrame(Seosan) ; Seosan.reset_index(drop=True, inplace=True) 
Anmyeondo = pd.DataFrame(Anmyeondo) ; Anmyeondo.reset_index(drop=True, inplace=True) 
Daecheon = pd.DataFrame(Daecheon) ; Daecheon.reset_index(drop=True, inplace=True) 
Seocheon = pd.DataFrame(Seocheon) ; Seocheon.reset_index(drop=True, inplace=True) 
Gunsan = pd.DataFrame(Gunsan) ; Gunsan.reset_index(drop=True, inplace=True) 
Mokpo = pd.DataFrame(Mokpo) ; Mokpo.reset_index(drop=True, inplace=True) 
Jeonnam_western_fish_farming = pd.DataFrame(Jeonnam_western_fish_farming) ; Jeonnam_western_fish_farming.reset_index(drop=True, inplace=True) 
Goheung_gun = pd.DataFrame(Goheung_gun) ; Goheung_gun.reset_index(drop=True, inplace=True) 
Yeosu = pd.DataFrame(Yeosu) ; Yeosu.reset_index(drop=True, inplace=True) 
Namhae_gun = pd.DataFrame(Namhae_gun) ; Namhae_gun.reset_index(drop=True, inplace=True) 
Tongyeong = pd.DataFrame(Tongyeong) ; Tongyeong.reset_index(drop=True, inplace=True) 
Geoje = pd.DataFrame(Geoje) ; Geoje.reset_index(drop=True, inplace=True) 
Busan = pd.DataFrame(Busan) ; Busan.reset_index(drop=True, inplace=True) 
Ulsan = pd.DataFrame(Ulsan) ; Ulsan.reset_index(drop=True, inplace=True) 
Pohang = pd.DataFrame(Pohang) ; Pohang.reset_index(drop=True, inplace=True) 
Samcheok = pd.DataFrame(Samcheok) ; Samcheok.reset_index(drop=True, inplace=True) 
Gangneung = pd.DataFrame(Gangneung) ; Gangneung.reset_index(drop=True, inplace=True) 
Sokcho = pd.DataFrame(Sokcho) ; Sokcho.reset_index(drop=True, inplace=True) 
Donghae = pd.DataFrame(Donghae) ; Donghae.reset_index(drop=True, inplace=True)

# %%
# csv파일로 저장
pd.DataFrame(Incheon).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/감성돔/Incheon.csv', index=False)
pd.DataFrame(Seosan).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/감성돔/Seosan.csv', index=False)
pd.DataFrame(Anmyeondo).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/감성돔/Anmyeondo.csv', index=False)
pd.DataFrame(Daecheon).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/감성돔/Daecheon.csv', index=False)
pd.DataFrame(Seocheon).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/감성돔/Seocheon.csv', index=False)
pd.DataFrame(Gunsan).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/감성돔/Gunsan.csv', index=False)
pd.DataFrame(Mokpo).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/감성돔/Mokpo.csv', index=False)
pd.DataFrame(Jeonnam_western_fish_farming).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/감성돔/Jeonnam_western_fish_farming.csv', index=False)
pd.DataFrame(Goheung_gun).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/감성돔/Goheung_gun.csv', index=False)
pd.DataFrame(Yeosu).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/감성돔/Yeosu.csv', index=False)
pd.DataFrame(Namhae_gun).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/감성돔/Namhae_gun.csv', index=False)
pd.DataFrame(Tongyeong).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/감성돔/Tongyeong.csv', index=False)
pd.DataFrame(Geoje).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/감성돔/Geoje.csv', index=False)
pd.DataFrame(Busan).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/감성돔/Busan.csv', index=False)
pd.DataFrame(Ulsan).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/감성돔/Ulsan.csv', index=False)
pd.DataFrame(Pohang).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/감성돔/Pohang.csv', index=False)
pd.DataFrame(Samcheok).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/감성돔/Samcheok.csv', index=False)
pd.DataFrame(Gangneung).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/감성돔/Gangneung.csv', index=False)
pd.DataFrame(Sokcho).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/감성돔/Sokcho.csv', index=False)
pd.DataFrame(Donghae).to_csv('/content/drive/MyDrive/멀티캠퍼스/2조/감성돔/Donghae.csv', index=False)
